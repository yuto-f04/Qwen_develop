# %% [markdown]
# # Colab Runner — 嘘キャンパスツアーガイド音声生成
#
# **このノートブックはコードを書く場所ではありません。**
# GitHub からコードを取得して `app.py` を起動するだけの薄い実行ランナーです。
#
# 開発・修正はローカル環境 (VS Code + Claude Code) で行い、GitHub に push してからここで `git pull` して実行してください。
#
# ## 実行手順
# 1. Cell 1: リポジトリの取得 (初回は clone、2回目以降は pull)
# 2. Cell 2: 依存パッケージのインストール
# 3. Cell 3: Gradio アプリ起動 (share=True で公開 URL を取得)

# %%
# ===== Cell 1: リポジトリの取得（ここだけ変わらない）=====
import os
REPO = "/content/Qwen_develop"
if os.path.exists(REPO):
    # !git -C {REPO} pull
else:
    # !git -C /content clone https://github.com/yuto-f04/Qwen_develop.git
print("完了:", REPO)

# %%
# ===== Cell 2: 環境セットアップ（中身はリポジトリのスクリプトに委譲）=====
# このセルは今後変更不要。ロジックは setup_colab.py / requirements.txt 側で管理する
# !python /content/Qwen_develop/setup_colab.py
# !pip install -q -r /content/Qwen_develop/requirements.txt

# %%
# ===== Cell 3: Gradio アプリ起動 =====
import os; os.chdir("/content/Qwen_develop")
# !python app.py
