# %% [markdown]
# # Colab Runner — 嘘キャンパスツアーガイド音声生成
#
# **このノートブックはコードを書く場所ではありません。**
# GitHub からコードを取得して `app.py` を起動するだけの薄い実行ランナーです。
#
# 開発・修正はローカル環境 (VS Code + Claude Code) で行い、GitHub に push してからここで `git pull` して実行してください。
#
# ## 実行手順
# 1. Cell 1: リポジトリの取得 (初回は clone、2回目以降は pull)
# 2. Cell 2: 依存パッケージのインストール
# 3. Cell 3: Gradio アプリ起動 (share=True で公開 URL を取得)

# %%
# ===== Cell 1: リポジトリの取得 =====
import os

# 常に /content から始める（何度実行しても Qwen_develop が入れ子にならないように）
os.chdir('/content')

REPO_URL = "https://github.com/yuto-f04/Qwen_develop.git"
REPO_DIR = "Qwen_develop"

if os.path.exists(REPO_DIR):
    print("リポジトリ取得済み。最新版に更新します...")
    # !git -C {REPO_DIR} pull
else:
    print("リポジトリをクローンします...")
    # !git clone {REPO_URL}

# %cd {REPO_DIR}
print(f"作業ディレクトリ: {os.getcwd()}")

# %%
# ===== Cell 2: 依存パッケージのインストール =====
# torch は Colab に事前インストール済みのため除外
# !pip install -q -r requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.8/183.8 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 30.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 29.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.1/87.1 kB 1.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.5/113.5 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.9/380.9 kB 23.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 64.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 58.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.3/32.3 MB 25.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 29.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.5/247.5 kB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.7/197.7 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 63.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 4.9 MB/s eta 0:00:00
#   Building wheel for demucs (setup.py) ... done
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Building wheel for dora-search (pyproject.toml) ... done
#   Building wheel for sox (setup.py) ... done

# %%
# ===== Cell 3: Gradio アプリ起動 =====
# share=True で公開 URL が発行される (約72時間有効)
# !python app.py
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://6bfa0d4ffa49446064.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
